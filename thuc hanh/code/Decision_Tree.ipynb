# %% [markdown]
# DECISION TREE (CÂY QUYẾT ĐỊNH)
# + Giúp bạn đưa ra quyết định dựa trên kinh nghiệm trước đó

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("D:/Machine Learning/thuc hanh/datasets/shows.csv")
df
# Out:
#     Age  Experience  Rank Nationality   Go
# 0    36          10     9          UK   NO
# 1    42          12     4         USA   NO
# 2    23           4     6           N   NO
# 3    52           4     4         USA   NO
# 4    43          21     8         USA  YES
# 5    44          14     5          UK   NO
# 6    66           3     7           N  YES
# 7    35          14     9          UK  YES
# 8    52          13     7           N  YES
# 9    35           5     9           N  YES
# 10   24           3     5         USA   NO
# 11   18           3     7          UK  YES
# 12   45           9     9          UK  YES

# %%
# de tao cay quyet dinh, tat ca du lieu phai o dang so
# tien xu li du lieu
df['Nationality']=LabelEncoder().fit_transform(df['Nationality'])
df['Go']=LabelEncoder().fit_transform(df['Go'])
df
# Out:
#     Age  Experience  Rank  Nationality  Go
# 0    36          10     9            1   0
# 1    42          12     4            2   0
# 2    23           4     6            0   0
# 3    52           4     4            2   0
# 4    43          21     8            2   1
# 5    44          14     5            1   0
# 6    66           3     7            0   1
# 7    35          14     9            1   1
# 8    52          13     7            0   1
# 9    35           5     9            0   1
# 10   24           3     5            2   0
# 11   18           3     7            1   1
# 12   45           9     9            1   1

# %%
X=df.iloc[:,0:4]
y=df['Go']

# %%
from sklearn.tree import DecisionTreeClassifier
from matplotlib import pyplot as plt
from sklearn import tree

# %%
X[2]

# %%
dtree=DecisionTreeClassifier()
dtree=dtree.fit(X,y)
tree.plot_tree(dtree)
# Out:
# [Text(0.2857142857142857, 0.9, 'x[2] <= 6.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.14285714285714285, 0.7, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.42857142857142855, 0.7, 'x[2] <= 8.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.2857142857142857, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5714285714285714, 0.5, 'x[0] <= 35.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.42857142857142855, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7142857142857143, 0.3, 'x[0] <= 40.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5714285714285714, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8571428571428571, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
print(dtree.predict([[40, 10, 6, 1]]))
# Out:
# [0]
# c:\Users\Asus-FPT\anaconda3\envs\ML01\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
