# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv("D:/Machine Learning/thuc hanh/datasets/full_data.csv")

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %%
df.shape
# Out:
# (4981, 11)

# %%
df.info
# Out:
# <bound method DataFrame.info of       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
# xoa cac hang ma gia tri cot smoking_status "unknow"
df.drop(df.index[(df["smoking_status"] == "Unknown")],axis=0,inplace=True)

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %%
# chuan hoa du lieu cac cot du lieu khong phai dang so
from sklearn.preprocessing import LabelEncoder

# %%
# chuan hoa gioi tinh: male:1
df['gender']=LabelEncoder().fit_transform(df['gender'])

# chuan hoa hon nhan; yes:1
df['ever_married']=LabelEncoder().fit_transform(df['ever_married'])

# chuan hoa cot loai hinhf lam viec: Govt_job:0; Private:1;Self-employed:2
df['work_type']=LabelEncoder().fit_transform(df['work_type'])

#  Urban:1 ; Rural	:0
df['Residence_type']=LabelEncoder().fit_transform(df['Residence_type'])

# formerly smoked:0; never smoked:1; smokes:2 

df['smoking_status']=LabelEncoder().fit_transform(df['smoking_status'])
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          1
# 1          1  80.0             0              1             1          1
# 2          0  49.0             0              0             1          1
# 3          0  79.0             1              0             1          2
# 4          1  81.0             0              0             1          1
# ...      ...   ...           ...            ...           ...        ...
# 4976       1  41.0             0              0             0          1
# 4977       1  40.0             0              0             1          1
# 4978       0  45.0             1              0             1          0
# 4979       1  40.0             0              0             1          1
# 4980       0  80.0             1              0             1          1
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# ...

# %%
# df.to_csv('D:/Machine Learning/thuc hanh/datasets/full_data(1).csv',index=False)
